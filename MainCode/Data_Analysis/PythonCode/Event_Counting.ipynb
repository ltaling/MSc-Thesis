# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import matplotlib.patches as patches

# %%
# Ignore this cell!
# Define Data for momentum off

#Total,DIS,1232RES,Other


# total_min_off = [1588677, 1390423, 53635, 144619]
# pi_selection_min_off = [544284, 439283, 38488, 66513]
# fiducials_min_off = [106006, 84410, 6765, 14831]
# pi_acceptance_min_off = [52244, 40557, 3408, 8279]

# total_plus_off = [1685759, 1449007, 54852, 181900]
# pi_selection_plus_off = [622625, 480638, 39681, 102306]
# fiducials_plus_off = [225518, 183366, 10031, 32121]
# pi_acceptance_plus_off = [98653, 77832, 4362, 16458]

# ind = np.arange(4)

# %%
#Ignore this cell!
# Define Data for momentum on

#Total,DIS,1232RES,Other

# total_min_on = [1463314, 1294012, 44709, 124593]
# pi_selection_min_on = [572096, 466338, 36629, 69129]
# fiducials_min_on = [103518, 82294, 6511, 14713]
# pi_acceptance_min_on = [53321, 41241, 3456, 8622]

# total_plus_on = [1555570, 1350761, 45184, 159625]
# pi_selection_plus_on = [643489, 503369, 37040, 103080]
# fiducials_plus_on = [209041, 170555, 8775, 29711]
# pi_acceptance_plus_on = [101569, 80192, 4459, 16917]

# %%
# Keep this cell

#Total,DIS,1232RES,Other

truth_min = [1638286, 981879, 228924, 427483]
momentum_min = [1407472, 860382, 187200, 359890]
fiducials_min = [108102, 57782, 17318, 33002]
pi_selection_min = [92598, 48445, 16705, 27448]
pi_acceptance_min = [72035, 38178, 12601, 21255]

truth_plus = [1773149, 1012368, 232912, 527869]
momentum_plus = [1514920, 875683, 186881, 452356]
fiducials_plus = [190407, 104566, 24496, 61345]
pi_selection_plus = [171044, 91681, 23867, 55496]
pi_acceptance_plus = [97459, 50972, 12530, 33956]

ind = np.arange(4)

# %%
# Create figure

labels = ['Total', 'DIS', '1232 RES', 'Other']

fig = plt.figure()
ax = fig.add_subplot(111)

# Multiple bar chart for momentum off and min

ax.bar(x=ind, height=truth_min, width=0.55, align='center',label='Truth')
ax.bar(x=ind, height=momentum_min, width=0.55,  align='center',label='After Momentum Threshold')
ax.bar(x=ind, height=fiducials_min, width=0.55,  align='center',label='After Fiducials')
ax.bar(x=ind, height=pi_selection_min, width=0.55,  align='center',label='After 1$\pi$ Selection')
ax.bar(x=ind, height=pi_acceptance_min, width=0.55,  align='center',label='After $\pi$ Acceptance Weighting')

# Define x-ticks

plt.xticks(ind, labels)
plt.legend()
plt.title("Number of Events Containing $\pi^{-}$ After Each Analysis Step")

# Layout and Display

plt.tight_layout()
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/Bar_Graphs/piminus_NoOfEvents.pdf")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Multiple bar chart for momentum off and plus

ax.bar(x=ind, height=truth_plus, width=0.55, align='center',label='Truth')
ax.bar(x=ind, height=momentum_plus, width=0.55,  align='center',label='After Momentum Threshold')
ax.bar(x=ind, height=fiducials_plus, width=0.55,  align='center',label='After Fiducials')
ax.bar(x=ind, height=pi_selection_plus, width=0.55,  align='center',label='After 1$\pi$ Selection')
ax.bar(x=ind, height=pi_acceptance_plus, width=0.55,  align='center',label='After $\pi$ Acceptance Weighting')

# Define x-ticks

plt.xticks(ind, labels)
plt.legend()
plt.title("  Number of Events Containing $\pi^{+}$ After Each Analysis Step")

# Layout and Display

plt.tight_layout()
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/Bar_Graphs/piplus_NoOfEvents.pdf")
plt.show()

# %%
#Graph making part 2: Heat map

data_array = [[0, 868611, 276558, 63463],
             [109041, 111852, 39910, 7044],
             [11163, 10730, 3112, 596],
             [2559, 1128, 311, 34]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(4))
ax.set_xticklabels(['0','1','2','3+'])
ax.set_xlabel("Number of Pions Above Threshold")
ax.set_yticks(np.arange(4))
ax.set_yticklabels(['0','1','2','3+'])
ax.set_ylabel("Number of Pions Below Threshold")

im = ax.imshow(np.asarray(data_array), cmap='Blues',norm=LogNorm(vmin=0.01,vmax=1e6))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("DIS")
ax.invert_yaxis()
#plt.savefig("Event_numbers/Heatmaps/DIS_map.pdf")
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/Heat_Maps/Momentum_Threshold/DIS_map.pdf")
plt.show()

# %%
data_array = [[0, 337417, 11374, 161],
             [70001, 13974, 396, 3],
             [2706, 232, 4, 0],
             [41, 2, 0, 0]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(4))
ax.set_xticklabels(['0','1','2','3+'])
ax.set_xlabel("Number of Pions Above Threshold")
ax.set_yticks(np.arange(4))
ax.set_yticklabels(['0','1','2','3+'])
ax.set_ylabel("Number of Pions Below Threshold")

im = ax.imshow(np.asarray(data_array), cmap='Blues',norm=LogNorm(vmin=0.01,vmax=1e6))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("$\Delta$(1232) Resonance")
ax.invert_yaxis()
#plt.savefig("Event_numbers/Heatmaps/1232RES_map.pdf")
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/Heat_Maps/Momentum_Threshold/1232RES_map.pdf")
plt.show()

# %%
data_array = [[0, 501418, 118692, 2821],
             [67331, 64957, 5101, 80],
             [7007, 2200, 101, 3],
             [267, 40, 1, 0]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(4))
ax.set_xticklabels(['0','1','2','3+'])
ax.set_xlabel("Number of Pions Above Threshold")
ax.set_yticks(np.arange(4))
ax.set_yticklabels(['0','1','2','3+'])
ax.set_ylabel("Number of Pions Below Threshold")

im = ax.imshow(np.asarray(data_array), cmap='Blues',norm=LogNorm(vmin=0.01,vmax=1e6))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Other")
ax.invert_yaxis()
#plt.savefig("Event_numbers/Heatmaps/Other_map.pdf")
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/Heat_Maps/Momentum_Threshold/OTHER_map.pdf")
plt.show()

# %%
data_array = [[0, 1.70745e6, 406624, 66445],
             [246373, 190783, 45407, 7127],
             [20876, 13162, 3217, 599],
             [2867, 1170, 312, 34]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(4))
ax.set_xticklabels(['0','1','2','3+'])
ax.set_xlabel("Number of Pions Above Threshold")
ax.set_yticks(np.arange(4))
ax.set_yticklabels(['0','1','2','3+'])
ax.set_ylabel("Number of Pions Below Threshold")

im = ax.imshow(np.asarray(data_array), cmap='Blues',norm=LogNorm(vmin=0.01,vmax=1e6))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Total")
ax.invert_yaxis()
#plt.savefig("Event_numbers/Heatmaps/Total_map.pdf")
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/Heat_Maps/Momentum_Threshold/TOTAL_map.pdf")
plt.show()

# %% [markdown]
# # Fiducial Heat Maps

# %%
#Graph making part 2: Heat map

data_array = [[0, 87837, 7752, 413],
             [129632, 40342, 4125, 107],
             [40960, 10383, 682, 27],
             [9945, 1552, 93, 1]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(4))
ax.set_xticklabels(['0','1','2','3+'])
ax.set_xlabel("Pions Passing Fiducial & Momentum Cuts")
ax.set_yticks(np.arange(4))
ax.set_yticklabels(['0','1','2','3+'])
ax.set_ylabel("Pions Failing Fiducial & Momentum Cuts")

im = ax.imshow(np.asarray(data_array), cmap='Blues',norm=LogNorm(vmin=0.01,vmax=1e6))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("DIS")
ax.invert_yaxis()

# Create a Rectangle patch
sq1 = patches.Rectangle((-0.5, 0.5), 1, 1, linewidth=2, edgecolor='yellow', facecolor=None ,fill=False,linestyle='--')
sq2 = patches.Rectangle((0.5, -0.5), 1, 1, linewidth=2, edgecolor='yellow', facecolor=None ,fill=False,linestyle='--')
rect = patches.Rectangle((0.5, -0.5), 1, 4, linewidth=2, edgecolor='r', facecolor=None ,fill=False,linestyle='-')

# Add the patch to the Axes
#ax.add_patch(rect)
#ax.add_patch(sq1)
#ax.add_patch(sq2)

plt.savefig("../Presentation/DIS_map_pres.png")
plt.show()

# %%
data_array = [[0, 37672, 620, 2],
             [49002, 2896, 33, 0],
             [2657, 61, 0, 0],
             [49, 0, 0, 0]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(4))
ax.set_xticklabels(['0','1','2','3+'])
ax.set_xlabel("Pions Passing Fiducial & Momentum Cuts")
ax.set_yticks(np.arange(4))
ax.set_yticklabels(['0','1','2','3+'])
ax.set_ylabel("Pions Failing Fiducial & Momentum Cuts")

im = ax.imshow(np.asarray(data_array), cmap='Blues',norm=LogNorm(vmin=0.01,vmax=1e6))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("$\Delta$(1232) Resonance")
ax.invert_yaxis()
# Create a Rectangle patch
sq1 = patches.Rectangle((-0.5, 0.5), 1, 1, linewidth=2, edgecolor='yellow', facecolor=None ,fill=False,linestyle='--')
sq2 = patches.Rectangle((0.5, -0.5), 1, 1, linewidth=2, edgecolor='yellow', facecolor=None ,fill=False,linestyle='--')
rect = patches.Rectangle((0.5, -0.5), 1, 4, linewidth=2, edgecolor='r', facecolor=None ,fill=False,linestyle='-')

# Add the patch to the Axes
# ax.add_patch(rect)
# ax.add_patch(sq1)
# ax.add_patch(sq2)
plt.savefig("../Presentation/1232RES_map_pres.png")
plt.show()

# %%
data_array = [[0, 60558, 5497, 63],
             [68376, 21386, 481, 0],
             [16456, 1006, 9, 0],
             [673, 13, 0, 0]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(4))
ax.set_xticklabels(['0','1','2','3+'])
ax.set_xlabel("Pions Passing Fiducial & Momentum Cuts")
ax.set_yticks(np.arange(4))
ax.set_yticklabels(['0','1','2','3+'])
ax.set_ylabel("Pions Failing Fiducial & Momentum Cuts")

im = ax.imshow(np.asarray(data_array), cmap='Blues',norm=LogNorm(vmin=0.01,vmax=1e6))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Other")
ax.invert_yaxis()
# Create a Rectangle patch
sq1 = patches.Rectangle((-0.5, 0.5), 1, 1, linewidth=2, edgecolor='yellow', facecolor=None ,fill=False,linestyle='--')
sq2 = patches.Rectangle((0.5, -0.5), 1, 1, linewidth=2, edgecolor='yellow', facecolor=None ,fill=False,linestyle='--')
rect = patches.Rectangle((0.5, -0.5), 1, 4, linewidth=2, edgecolor='r', facecolor=None ,fill=False,linestyle='-')

# Add the patch to the Axes
# ax.add_patch(rect)
# ax.add_patch(sq1)
# ax.add_patch(sq2)
plt.savefig("../Presentation/OTHER_map_pres.png")
plt.show()

# %%
data_array = [[0, 186067, 13869, 478],
             [247010, 64624, 4639, 107],
             [60073, 11450, 691, 27],
             [10667, 1565, 93, 1]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(4))
ax.set_xticklabels(['0','1','2','3+'])
ax.set_xlabel("Pions Passing Fiducial & Momentum Cuts")
ax.set_yticks(np.arange(4))
ax.set_yticklabels(['0','1','2','3+'])
ax.set_ylabel("Pions Failing Fiducial & Momentum Cuts")

im = ax.imshow(np.asarray(data_array), cmap='Blues',norm=LogNorm(vmin=0.01,vmax=1e6))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Total")
ax.invert_yaxis()
# Create a Rectangle patch
sq1 = patches.Rectangle((-0.5, 0.5), 1, 1, linewidth=2, edgecolor='yellow', facecolor=None ,fill=False,linestyle='--')
sq2 = patches.Rectangle((0.5, -0.5), 1, 1, linewidth=2, edgecolor='yellow', facecolor=None ,fill=False,linestyle='--')
rect = patches.Rectangle((0.5, -0.5), 1, 4, linewidth=2, edgecolor='r', facecolor=None ,fill=False,linestyle='-')

# Add the patch to the Axes
# ax.add_patch(rect)
# ax.add_patch(sq1)
# ax.add_patch(sq2)
plt.savefig("../Presentation/TOTAL_map_pres.png")
plt.show()

# %% [markdown]
# # True/False Graphs

# %%
# DIS Pi min

data_array = [[60733, 11976],
             [70832, 36469]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(2))
ax.set_xticklabels(['No','Yes'])
ax.set_xlabel("Pion Reconstructed")
ax.set_yticks(np.arange(2))
ax.set_yticklabels(['No','Yes'])
ax.set_ylabel("Pion Truth")

im = ax.imshow(np.asarray(data_array), cmap='BuGn',vmin=1000,vmax=70000)
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Was it DIS 1e1$\pi^{-}$ ?")
ax.invert_yaxis()
plt.text(-0.25,0.98,"70,832",color='white',size='x-large')
plt.text(0.75,0.98,"36,469",color='black',size='x-large')
plt.text(-0.25,-0.05,"60,733",color='white',size='x-large')
plt.text(0.75,-0.05,"11,976",color='black',size='x-large')
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/TrueFalse_Graphs/DIS_min_TF.pdf")
plt.show()

# %%
# DIS Pi plus

data_array = [[62288, 40297],
             [58809, 51384]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(2))
ax.set_xticklabels(['No','Yes'])
ax.set_xlabel("Pion Reconstructed")
ax.set_yticks(np.arange(2))
ax.set_yticklabels(['No','Yes'])
ax.set_ylabel("Pion Truth")

im = ax.imshow(np.asarray(data_array), cmap='BuGn',vmin=1000,vmax=70000)
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Was it DIS 1e1$\pi^{+}$ ?")
ax.invert_yaxis()
plt.text(-0.25,0.98,"58,809",color='white',size='x-large')
plt.text(0.75,0.98,"51,384",color='white',size='x-large')
plt.text(-0.25,-0.05,"62,288",color='white',size='x-large')
plt.text(0.75,-0.05,"40,297",color='black',size='x-large')
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/TrueFalse_Graphs/DIS_plus_TF.pdf")
plt.show()

# %%
# RES Pi minus

data_array = [[3190, 2752],
             [27392, 15529]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(2))
ax.set_xticklabels(['No','Yes'])
ax.set_xlabel("Pion Reconstructed")
ax.set_yticks(np.arange(2))
ax.set_yticklabels(['No','Yes'])
ax.set_ylabel("Pion Truth")

im = ax.imshow(np.asarray(data_array), cmap='BuGn',vmin=10,vmax=30000)
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Was it $\Delta(1232)$ 1e1$\pi^{-}$ ?")
ax.invert_yaxis()
plt.text(-0.25,0.98,"27,392",color='white',size='x-large')
plt.text(0.75,0.98,"15,529",color='white',size='x-large')
plt.text(-0.25,-0.05,"3,190",color='black',size='x-large')
plt.text(0.75,-0.05,"2,752",color='black',size='x-large')
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/TrueFalse_Graphs/RES_minus_TF.pdf")
plt.show()

# %%
# RES Pi plus

data_array = [[3156, 2814],
             [21611, 22096]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(2))
ax.set_xticklabels(['No','Yes'])
ax.set_xlabel("Pion Reconstructed")
ax.set_yticks(np.arange(2))
ax.set_yticklabels(['No','Yes'])
ax.set_ylabel("Pion Truth")

im = ax.imshow(np.asarray(data_array), cmap='BuGn',vmin=10,vmax=30000)
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Was it $\Delta(1232)$ 1e1$\pi^{+}$ ?")
ax.invert_yaxis()
plt.text(-0.25,0.98,"21,611",color='white',size='x-large')
plt.text(0.75,0.98,"22,096",color='white',size='x-large')
plt.text(-0.25,-0.05,"3,156",color='black',size='x-large')
plt.text(0.75,-0.05,"2,814",color='black',size='x-large')
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/TrueFalse_Graphs/RES_plus_TF.pdf")
plt.show()

# %%
# OTHER Pi minus

data_array = [[22323, 21416],
             [33031, 20320]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(2))
ax.set_xticklabels(['No','Yes'])
ax.set_xlabel("Pion Reconstructed")
ax.set_yticks(np.arange(2))
ax.set_yticklabels(['No','Yes'])
ax.set_ylabel("Pion Truth")

im = ax.imshow(np.asarray(data_array), cmap='BuGn',vmin=1000,vmax=40000)
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Was it OTHER 1e1$\pi^{-}$ ?")
ax.invert_yaxis()
plt.text(-0.25,0.98,"33,031",color='white',size='x-large')
plt.text(0.75,0.98,"20,320",color='black',size='x-large')
plt.text(-0.25,-0.05,"22,323",color='black',size='x-large')
plt.text(0.75,-0.05,"21,416",color='black',size='x-large')
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/TrueFalse_Graphs/OTHER_minus_TF.pdf")
plt.show()

# %%
# OTHER Pi minus

data_array = [[22242, 21629],
             [35323, 40219]]

fig, ax = plt.subplots()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(2))
ax.set_xticklabels(['No','Yes'])
ax.set_xlabel("Pion Reconstructed")
ax.set_yticks(np.arange(2))
ax.set_yticklabels(['No','Yes'])
ax.set_ylabel("Pion Truth")

im = ax.imshow(np.asarray(data_array), cmap='BuGn',vmin=1000,vmax=40000)
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Events", rotation=-90, va="bottom")
ax.set_title("Was it OTHER 1e1$\pi^{+}$ ?")
ax.invert_yaxis()
plt.text(-0.25,0.98,"35,323",color='white',size='x-large')
plt.text(0.75,0.98,"40,219",color='white',size='x-large')
plt.text(-0.25,-0.05,"22,242",color='black',size='x-large')
plt.text(0.75,-0.05,"21,629",color='black',size='x-large')
plt.savefig("../FinalAct/C12_2261/Normal_study/Event_counting_graphs/TrueFalse_Graphs/OTHER_plus_TF.pdf")
plt.show()
